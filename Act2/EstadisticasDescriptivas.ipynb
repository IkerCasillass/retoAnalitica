# %%
import pandas as pd
import numpy as np

# %%
#importar tabla
df = pd.read_csv("COVID19MEXICO.csv")

# Ver información general del DataFrame, columnas y tipos de dato
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161242 entries, 0 to 161241
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   FECHA_ACTUALIZACION    161242 non-null  object
#  1   ID_REGISTRO            161242 non-null  object
#  2   ORIGEN                 161242 non-null  int64
#  3   SECTOR                 161242 non-null  int64
#  4   ENTIDAD_UM             161242 non-null  int64
#  5   SEXO                   161242 non-null  int64
#  6   ENTIDAD_NAC            161242 non-null  int64
#  7   ENTIDAD_RES            161242 non-null  int64
#  8   MUNICIPIO_RES          161242 non-null  int64
#  9   TIPO_PACIENTE          161242 non-null  int64
#  10  FECHA_INGRESO          161242 non-null  object
#  11  FECHA_SINTOMAS         161242 non-null  object
#  12  FECHA_DEF              161242 non-null  object
#  13  INTUBADO               161242 non-null  int64
# ...

# %%
print(df.head())
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2023-09-12      490e8d       1      12          19     2
# 1          2023-09-12      7ced56       2      12           9     2
# 2          2023-09-12      e19494       1      12          19     2
# 3          2023-09-12      80989f       2      12           7     1
# 4          2023-09-12      c9a5ed       2      12           9     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 0           19           19             43              1  ...       2.0
# 1            8            9              9              1  ...       2.0
# 2           28           19             25              1  ...       2.0
# 3            7            7             78              1  ...       2.0
# 4            9            9              9              1  ...       2.0
#
#   TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  RESULTADO_ANTIGENO  \
# ...

# %%
df.describe().T
# Out:
#                           count       mean        std  min   25%   50%   75%  \
# ORIGEN                 161242.0   1.721958   0.448035  1.0   1.0   2.0   2.0
# SECTOR                 161242.0   6.922464   3.929872  1.0   4.0   4.0  12.0
# ENTIDAD_UM             161242.0  14.869414   7.848233  1.0   9.0  13.0  21.0
# SEXO                   161242.0   1.412529   0.492291  1.0   1.0   1.0   2.0
# ENTIDAD_NAC            161242.0  15.414433   9.230258  1.0   9.0  14.0  21.0
# ENTIDAD_RES            161242.0  15.022488   7.802813  1.0   9.0  14.0  21.0
# MUNICIPIO_RES          161242.0  36.344569  53.022374  1.0   7.0  17.0  42.0
# TIPO_PACIENTE          161242.0   1.067948   0.251657  1.0   1.0   1.0   1.0
# INTUBADO               161242.0  90.571247  23.868753  1.0  97.0  97.0  97.0
# NEUMONIA               161241.0   1.973853   0.159573  1.0   2.0   2.0   2.0
# EDAD                   161241.0  40.123926  18.893029  0.0  27.0  38.0  53.0
# ...

# %%
hospitalizados = (df['TIPO_PACIENTE'] == 2).sum()

porcentajeHospitalizado = (hospitalizados/df['TIPO_PACIENTE'].count()) * 100

print("Porcentaje de pacientes de covid hospitalizados: " + str(porcentajeHospitalizado.round(3)))
# Out:
# Porcentaje de pacientes de covid hospitalizados: 6.795
